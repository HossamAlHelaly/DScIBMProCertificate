# %% [markdown]
# # Course III DS Methodoligy:

# %% [markdown]
# ## Week 1. From Problem to Approavh and from Requirements to Collection:
# >In this module, you will learn about why we are interested in data science, what a methodology is, and why data scientists need a methodology. You will also learn about the data science methodology and its flowchart. You will learn about the first two stages of the data science methodology, namely Business Understanding and Analytic Approach. Finally, through a lab session, you will also obtain how to complete the Business Understanding and the Analytic Approach stages and the Data Requirements and Data Collection stages pertaining to any data science problem.

# %% [markdown]
# ### Welcome:
# #### Data?
# * We need to have a solid understand of the problem at hand in order to be able to resolve it
# * Based on our understanding of the question we can build a view of how to best use our data to reach a solution for our problem
#
# #### Methodology:
# * A system of methods used in a particular area of study or activity
# * Jumping directly to solution without having to pass over methodology isn't always right or time saving
# * Methodology used in DS
#
# #### DS Methodology:
# * Aims at answering 10 basic questions in a prescribed sequence:
#
# ##### Form Problem to Approach:
# 1. What's the Problem?
# 2. How can you use data to answer the question?
#
# ##### Working with the data?
# 3. What data do you  need to use to answer the question?
# 4. Where is the data coming from? and How will you get it?
# 5. Is the Data representative of the problem?
# 6. What Additional work required to manipulate and work with the data?
#
# ##### Deriving the answer..
# 7. Best VIZ techniques to approach your answer using your data?
# 8. Does the model used really answer the question? or more modifications are needed?
# 9. Can you put the model into practice?
# 10. Can you get a constructive feedback?

# %% [markdown]
# ### What is CRISP-DM?
# >The CRISP-DM methodology is a process aimed at increasing the use of data mining over a wide variety of business applications and industries. The intent is to take case specific scenarios and general behaviors to make them domain neutral. CRISP-DM is comprised of six steps with an entity that has to implement in order to have a reasonable chance of success.
# * Business Understanding
# * Data Understanding
# * Data Preparation
# * Modelling
# * Evaluation
# * Deployment

# %% [markdown]
# ### Busness Understanding:
# #### The Importance of Questions:
# #### From understanding to approach
# * Having the right questions is vital
# * Business Understanding:
#     * What's the problem that you're trying to solve?
# * Analytic Approach:
#     * How can you use data to answer the questions?
#
# * Establishing the right questions depends on your understanding of the goal of your process
#
# #### Supporting the goal:
# * Define the goals
# * Define the objectives

# %% [markdown]
# ### Analytic Approach:
# * The approach involves seeking clarification from the person who is asking the question,
#
#
# #### Types of Questions:
# * If the question is to detemine probablities of an action:
#     * Use a predictive model
# * If the question is to show relationships:
#     * Use a descriptive model
# * If the question requires a yes/no question:
#     * Use a classification model

# %% [markdown]
# ### Data Requirements:
# #### What are Data Reuirements:
# * Idetifing the data as to:
#     * What?
#     * Where?
#     * When?
#     * Why?
#     * How?
#     * Who?
#
# * Data Collection:
#     * What occurs during data collection?

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import re

# %%
recipes = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0103EN-SkillsNetwork/labs/Module%202/recipes.csv')
recipes.head(5)
# Out:
#       country almond angelica anise anise_seed apple apple_brandy apricot  \
# 0  Vietnamese     No       No    No         No    No           No      No
# 1  Vietnamese     No       No    No         No    No           No      No
# 2  Vietnamese     No       No    No         No    No           No      No
# 3  Vietnamese     No       No    No         No    No           No      No
# 4  Vietnamese     No       No    No         No    No           No      No
#
#   armagnac artemisia artichoke asparagus avocado bacon baked_potato balm  \
# 0       No        No        No        No      No    No           No   No
# 1       No        No        No        No      No    No           No   No
# 2       No        No        No        No      No    No           No   No
# 3       No        No        No        No      No    No           No   No
# 4       No        No        No        No      No    No           No   No
#
#   banana barley bartlett_pear basil bay bean beech beef beef_broth beef_liver  \
# ...

# %%
recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57691 entries, 0 to 57690
# Columns: 384 entries, country to zucchini
# dtypes: object(384)
# memory usage: 169.0+ MB
